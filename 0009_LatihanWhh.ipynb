# %% [markdown]
# <a href="https://colab.research.google.com/github/EkoAs/GoogleColab.Py/blob/main/0009_LatihanWhh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r


def hell():
  print(f"welcome back to my f")
  user = input(f"typing something: ")
  print(f"you typing {user}")
  print(f"Length {len(user)}")
  # Checking if 'u' exists as a string and showing its index
  found = 'u' in user
  index = user.find('u')
  print(f"Is 'u' in string? {str(found)}")
  print(f"Index of 'u': {index}")


hell()
# Out:
# welcome back to my f
# typing something: hv c u
# you typing hv c u
# Length 6
# Is 'u' in string? True
# Index of 'u': 5
